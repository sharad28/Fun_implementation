# %% [markdown]
# <a href="https://colab.research.google.com/github/sharad28/Fun_implementation/blob/main/CNN/Implementation_of_basic_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
car_path = "/content/drive/MyDrive/Colab Notebooks/Deep learning/Day 14/car1.jpeg"

# %%
car = cv2.imread(car_path)
car_rgb = cv2.cvtColor(car,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(car_rgb,cmap="gray")

# %%
car_rgb.shape
# Out:
# (168, 300, 3)

# %%
filters=5
conv_layer = tf.keras.layers.Conv2D(filters=filters,kernel_size=3,input_shape=car_rgb.shape)
model = tf.keras.Sequential(conv_layer)
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 166, 298, 5)       140
#
# ...
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________

# %%
row,col,depth = car_rgb.shape
print(car_rgb.shape)
car_rgb_reshape = car_rgb.reshape(1,row,col,depth)
# Out:
# (168, 300, 3)

# %%
out = model.predict(car_rgb_reshape)
_,row,col,depth = out.shape

# %%
out= out.reshape(row,col,depth)
# plt.imshow(out)
for i in range(filters):
  plt.imshow(out[:,:,i],cmap="gray")
  plt.show()
